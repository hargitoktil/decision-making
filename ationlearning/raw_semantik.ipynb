# %%
import pandas as pd
df = pd.read_csv('semantik.csv')

#tampilkan data semantik 10 baris pertama
df.head()
# Out:
#                               nama_diklat       start         end  jamlat  \
# 0  Pelatihan Tata Naskah Dinas Angkatan I  10/01/2019  24/01/2019    35.0
# 1  Pelatihan Tata Naskah Dinas Angkatan I  10/01/2019  24/01/2019    35.0
# 2  Pelatihan Tata Naskah Dinas Angkatan I  10/01/2019  24/01/2019    35.0
# 3  Pelatihan Tata Naskah Dinas Angkatan I  10/01/2019  24/01/2019    35.0
# 4  Pelatihan Tata Naskah Dinas Angkatan I  10/01/2019  24/01/2019    35.0
#
#                     satker_panitia     tipe                            biaya  \
# 0  Balai Diklat Keuangan Palembang  REGULAR  Balai Diklat Keuangan Palembang
# 1  Balai Diklat Keuangan Palembang  REGULAR  Balai Diklat Keuangan Palembang
# 2  Balai Diklat Keuangan Palembang  REGULAR  Balai Diklat Keuangan Palembang
# 3  Balai Diklat Keuangan Palembang  REGULAR  Balai Diklat Keuangan Palembang
# 4  Balai Diklat Keuangan Palembang  REGULAR  Balai Diklat Keuangan Palembang
#
# ...

# %%
# kolom-kolom dalam data semantik
df.columns
# Out:
# Index(['nama_diklat', 'start', 'end', 'jamlat', 'satker_panitia', 'tipe',
#        'biaya', 'biaya_detail', 'ujian', 'class', 'classs', 'id',
#        'nama_peserta', 'nip', 'nrp_nik', 'born', 'birthday', 'gender', 'hp',
#        'email', 'office_address', 'education', 'education_desc', 'position',
#        'posi_desc', 'status', 'agama', 'main_unit', 'eselon2', 'eselon3',
#        'eselon4', 'satker', 'test', 'graduation', 'ativity', 'presence',
#        'pretest', 'post_test', 'number', 'date_cert'],
#       dtype='object')

# %%
# tipe data apa aja dalam data semantik
df.nama_diklat.value_counts()
# Out:
# Seminar Bijak Bermedsos                                                                                                                                                                                                 765
# Seminar Mengawal Pertumbuhan Ekonomi Di Era Disrupsi Digital                                                                                                                                                            504
# Diklat Persiapan Purnabhakti Angkatan I                                                                                                                                                                                 491
# Pelatihan Tata Naskah Dinas Angkatan II                                                                                                                                                                                 464
# ...

# %%
# jabatan peserta diklat pada data semantik
df.nama_diklat.count()
# Out:
# 53585

# %%
df_filter = df[['nama_diklat', 'start', 'end', 'jamlat', 'nama_peserta', 'nip', 'born', 'birthday', 'gender', 'ujian','eselon2', 'education', 'education_desc', 'posi_desc','satker_panitia']]
df_filter.head()
# Out:
#                               nama_diklat       start         end  jamlat  \
# 0  Pelatihan Tata Naskah Dinas Angkatan I  10/01/2019  24/01/2019    35.0
# 1  Pelatihan Tata Naskah Dinas Angkatan I  10/01/2019  24/01/2019    35.0
# 2  Pelatihan Tata Naskah Dinas Angkatan I  10/01/2019  24/01/2019    35.0
# 3  Pelatihan Tata Naskah Dinas Angkatan I  10/01/2019  24/01/2019    35.0
# 4  Pelatihan Tata Naskah Dinas Angkatan I  10/01/2019  24/01/2019    35.0
#
#             nama_peserta                   nip       born    birthday  gender  \
# 0  Nur Trisakses Apriani  ~ 198704162006022002  Palembang  16/04/1987  WANITA
# 1          Deni Asmayadi  ~ 198606112014021002   Sukabumi  11/06/1986    PRIA
# 2        Marisa Agustina  ~ 198308242002122001     Klaten  24/08/1983  WANITA
# 3         Emi Mawar Sari  ~ 197212182003122001  Palembang  18/12/1972  WANITA
# 4           Else Herlina  ~ 196411241985092002  Palembang  24/11/1964  WANITA
#
# ...

# %%
df_widyaiswara = df_filter[df_filter['posi_desc'].str.contains('Wid+', na=False)]
df_widyaiswara.head()
# Out:
#                                            nama_diklat       start  \
# 391             Pelatihan Tata Naskah Dinas Angkatan I  24/01/2019
# 392             Pelatihan Tata Naskah Dinas Angkatan I  24/01/2019
# 419             Pelatihan Tata Naskah Dinas Angkatan I  24/01/2019
# 580             Pelatihan Tata Naskah Dinas Angkatan I  31/01/2019
# 592  Pelatihan Penyelesaian Sengketa/Perkara Melalu...  01/02/2019
#
#             end  jamlat               nama_peserta                   nip  \
# 391  08/02/2019    35.0         Efi Dyah Indrawati  ~ 197206291999032001
# 392  08/02/2019    35.0  Theresia Vera Yuliastanti  ~ 197707021999032001
# 419  08/02/2019    35.0              Eri Hariyanto  ~ 197309011994021001
# 580  15/02/2019    55.0                Koko Inarto  ~ 198404132004121003
# 592  01/03/2019   151.0             Agus Suharsono  ~ 196912311995031001
#
#            born    birthday  gender  ujian  \
# 391      Malang  29/06/1972  WANITA  TIDAK
# ...

# %%
df['nama_diklat'].value_counts()
# Out:
# Seminar Bijak Bermedsos                                                                                                                                                                                                 765
# Seminar Mengawal Pertumbuhan Ekonomi Di Era Disrupsi Digital                                                                                                                                                            504
# Diklat Persiapan Purnabhakti Angkatan I                                                                                                                                                                                 491
# Pelatihan Tata Naskah Dinas Angkatan II                                                                                                                                                                                 464
# ...

# %%
df_widyaiswara_csv = pd

# %%
df_widyaiswara_csv = df_widyaiswara.to_excel("datawi.xlsx")

# %%
data_wi = pd.read_csv('datawi.csv')
del data_wi['Column']
data_wi.tail()
# Out:
#                                    nama_diklat       start         end  \
# 1387  e-Learning Pengelolaan Utang Angkatan IV  21/10/2019  20/11/2019
# 1388  e-Learning Pengelolaan Utang Angkatan IV  21/10/2019  20/11/2019
# 1389  e-Learning Pengelolaan Utang Angkatan IV  21/10/2019  20/11/2019
# 1390  e-Learning Pengelolaan Utang Angkatan IV  21/10/2019  20/11/2019
# 1391  e-Learning Pengelolaan Utang Angkatan IV  21/10/2019  20/11/2019
#
#       jamlat           nama_peserta                   nip        born  \
# 1387     6.0             Supriyanto  ~ 197202051999031001  Kulonprogo
# 1388     6.0    Sampurna Budi Utama  ~ 197402191995021001  Yogyakarta
# 1389     6.0                 Suradi  ~ 196310251986031002      Sragen
# 1390     6.0         Hari Sugiharto  ~ 196709071988031001     Cirebon
# 1391     6.0  Dwi Rachmad Kurniawan  ~ 198012072002121001   Pamekasan
#
#         birthday gender ujian  \
# 1387  05/02/1972   PRIA    YA
# 1388  19/02/1974   PRIA    YA
# ...

# %%
plot_nama_wi = df_widyaiswara.nama_peserta.value_counts()
plot_nama_wi.head()
# Out:
# Sri Wahyuni                  23
# Theresia Vera Yuliastanti    22
# Agus Hekso Pramudijono       21
# Suwardi                      19
# Efi Dyah Indrawati           18
# Name: nama_peserta, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.hist(plot_nama_wi, bins = 15)
#plt.xticks()
plt.xlabel('distribusi jumlah diklat yang diikuti wi')
plt.show()

# %%
df_widyaiswara.nama_diklat.value_counts()
# Out:
# E-Learning Pengenalan Kementerian Keuangan Corporate University Angkatan IV                                                                                                                                             52
# Diklat Kewidyaiswaraan Berjenjang Madya                                                                                                                                                                                 51
# Widyaiswara Competency Update Angkatan III                                                                                                                                                                              50
# E-Learning Pengenalan Kementerian Keuangan Corporate University Angkatan III                                                                                                                                            39
# ...

# %%
plot_diklat = df_widyaiswara.nama_diklat.value_counts()
plt.hist(plot_diklat)
plt.xlabel('distribusi diklat yang sering diikuti')
plt.show()

# %%
df_wi_posidesc = df_widyaiswara['posi_desc']
df_wi_posidesc.value_counts()
# nama_jenjang = ['wi_pertama', 'wi_muda', 'wi_madya', 'wi_utama']
# Out:
# Widyaiswara Ahli Madya                                      708
# Widyaiswara Madya                                           190
# Widyaiswara Ahli Muda                                       171
# Widyaiswara Muda                                            109
# Widyaiswara Ahli Utama                                      104
# Widyaiswara Ahli Pertama                                     40
# Widyaiswara                                                  33
# Widyaiswara Utama                                            17
# Widyaiswara Pusdiklat Bea dan Cukai                           8
# Widyaiswara Pusat Pendidikan dan Pelatihan Bea dan Cukai      8
# Widyaiswara Alhi Utama                                        3
# Widayaiswara                                                  1
# Name: posi_desc, dtype: int64

# %%
plot_satker_wi = df_widyaiswara.satker_panitia.value_counts()
plot_satker_wi.head()
# Out:
# Pusat Pendidikan dan Pelatihan Keuangan Umum    1293
# Balai Diklat Keuangan Yogyakarta                  40
# Balai Diklat Keuangan Cimahi                      25
# Balai Diklat Keuangan Malang                       7
# Balai Diklat Keuangan Makassar                     7
# Name: satker_panitia, dtype: int64
