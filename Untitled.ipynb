# %%
price = 8000
# condition

if (price > 5000) and (price <= 10000):
    print("the price is standard")
elif price > 10000:
    print("the price is expensive")
else:
    print("the price is cheap")
# Out:
# the price is standard

# %%
price = 8000
# condition

if price > 10000:
    print("the price is expensive")
elif price > 5000:
    print("the price is standard")
else:
    print("the price is cheap")

print("test")
print("test")
print("test")
print("test")
# Out:
# the price is standard

# %%
# for looping --> certain iteration
# while looping --> uncertain iteration

# %%
my_list = [3,5,6,8]

#1 by element
for x in my_list:
    print(x*4)
# Out:
# 12
# 20
# 24
# 32

# %%
#2 by index
my_list = [3,5,6,8,13]
#idx_list = [0,1,2,3]
# range(init-opt, fin, interval-opt)
idx_list = range(len(my_list))

#for x in idx_list:
for x in range(len(my_list)):
#    my_list[x] = my_list[x] * 4
#    print(my_list[x], my_list[x] * 4)
    my_list[x] = my_list[x] * 4
my_list
# Out:
# [12, 20, 24, 32, 52]

# %%
range(3,10,2)
# Out:
# range(3, 10, 2)

# %%
# while
price = 100

# condition price <= 5
i = 0
while price > 5:
    price = price - (price * 0.01)
    print(price)
#    i = i + 1
#    # emergency exit
#    if i > 50:
#        break
# Out:
# 99.0
# 98.01
# 97.02990000000001
# 96.05960100000001
# 95.09900499000001
# 94.14801494010001
# 93.20653479069901
# 92.27446944279203
# 91.3517247483641
# 90.43820750088047
# 89.53382542587165
# 88.63848717161294
# 87.7521022998968
# 86.87458127689784
# 86.00583546412886
# 85.14577710948758
# 84.29431933839271
# 83.45137614500878
# 82.6168623835587
# 81.79069375972311
# 80.97278682212588
# 80.16305895390462
# 79.36142836436558
# 78.56781408072193
# 77.78213593991471
# 77.00431458051557
# 76.23427143471041
# 75.47192872036331
# 74.71720943315968
# 73.97003733882808
# 73.2303369654398
# 72.4980335957854
# 71.77305325982755
# 71.05532272722927
# 70.34476949995697
# 69.6413218049574
# 68.94490858690783
# 68.25545950103876
# 67.57290490602837
# 66.89717585696809
# 66.22820409839841
# 65.56592205741443
# 64.91026283684027
# 64.26116020847188
# 63.61854860638716
# 62.982363120323285
# 62.352539489120055
# 61.72901409422885
# 61.111723953286564
# 60.5006067137537
# 59.89560064661616
# ...

# %%
my_list = [3,5,6,8,13]
new_list = my_list[:]

#for x in idx_list:
#for x in range(len(my_list)):
i = 0
while len(my_list) > 0:  
    new_list[i] = new_list[i] * 4    
    print(my_list)
    my_list.remove(my_list[i])
    i = i + 1
new_list
# Out:
# [3, 5, 6, 8, 13]
# [5, 6, 8, 13]
# [5, 8, 13]
# [5, 8]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-41-43829b4953f5> in <module>
#       8     new_list[i] = new_list[i] * 4
#       9     print(my_list)
# ---> 10     my_list.remove(my_list[i])
#      11     i = i + 1
#      12 new_list
#
# IndexError: list index out of range
